# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Read data from file
df = pd.read_csv('epa-sea-level.csv')
df.head()
# Out:
#    Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0  1880                  0.000000          -0.952756           0.952756
# 1  1881                  0.220472          -0.732283           1.173228
# 2  1882                 -0.440945          -1.346457           0.464567
# 3  1883                 -0.232283          -1.129921           0.665354
# 4  1884                  0.590551          -0.283465           1.464567
#
#    NOAA Adjusted Sea Level
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
#Use matplotlib to create a scatter plot using the Year column as the x-axis
#and the CSIRO Adjusted Sea Level column as the y-axis.
x = df['Year']
y = df['CSIRO Adjusted Sea Level']
plt.scatter(x,y)
plt.show()

# %%
#Use the linregress function from scipy.stats to get the slope and y-intercept 
#of the line of best fit. Plot the line of best fit over the 
#top of the scatter plot. Make the line go through the year 2050 
#to predict the sea level rise in 2050.

slope, intercept, r_value, p_value, stderr = linregress(x,y)

#set the new x,y for a line plot
x_pred = pd.Series([i for i in range(1880,2051)])
y_pred = slope*x_pred + intercept

#create a line plot
plt.plot(x_pred,y_pred,'r')

# %%
# another way to find slope (easiest way)
# use linregress function and assign as an object for later use
res = linregress(x,y)
res
# Out:
# LinregressResult(slope=0.06304458401213482, intercept=-119.06594196773983, rvalue=0.984757131182585, pvalue=3.7886969791131554e-102, stderr=0.0009692118713287152, intercept_stderr=1.886943381242523)

# %%
#use that object to set up the graph

# set new x,y for a line plot
x_pred = pd.Series([i for i in range(1880,2051)])
y_pred = res.slope*x_pred + res.intercept

#create a line plot
plt.plot(x_pred,y_pred,'r')

# %%
# create second line of best fit
#set new range of data (from 2000 to the future)
df_forecast = df.loc[df['Year'] >= 2000]

#set new x,y for a new plot
x_forecast = df_forecast['Year']
y_forecast = df_forecast['CSIRO Adjusted Sea Level']

df_forecast
# Out:
#      Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 120  2000                  7.062992           6.791339           7.334646
# 121  2001                  7.287402           7.019685           7.555118
# 122  2002                  7.381890           7.110236           7.653543
# 123  2003                  7.759843           7.484252           8.035433
# 124  2004                  7.740157           7.464567           8.015748
# 125  2005                  7.744094           7.472441           8.015748
# 126  2006                  7.917323           7.645669           8.188976
# 127  2007                  7.996063           7.712598           8.279528
# 128  2008                  8.350394           8.078740           8.622047
# 129  2009                  8.586614           8.311024           8.862205
# 130  2010                  8.901575           8.618110           9.185039
# 131  2011                  8.964567           8.661417           9.267717
# ...

# %%
# get new slope + intercept using linregress() function 
#(from new range of data set (from 2000))
slope, intercept, r_value, p_value, stderr = linregress(x_forecast,y_forecast)

# set x, y for creating a new line graph
x_pred2 = pd.Series([i for i in range(2000,2050)])
y_pred2 = slope*x_pred2 + intercept

#create line graph with different color
plt.plot(x_pred2,y_pred2,'green')

# %%
# add all plots in 1 figure

# first scatter plot
fig, ax = plt.subplots(figsize=(6,6))
ax = plt.scatter(x=df['Year'], y=df['CSIRO Adjusted Sea Level'])

#line plot (1880-2050)
plt.plot(x_pred,y_pred,'r')

#line plot (2000-2050)
plt.plot(x_pred2,y_pred2,'green')

#Add labels and title
plt.title('Rise in Sea Level')
plt.xlabel('Year',fontsize=12)
plt.ylabel('Sea Level (inches)',fontsize=12)
# Out:
# Text(0, 0.5, 'Sea Level (inches)')
